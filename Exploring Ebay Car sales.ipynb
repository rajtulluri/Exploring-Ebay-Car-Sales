# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("autos.csv",encoding='Latin-1')

# %%
df.head(15)
# Out:
#             dateCrawled                                               name  \
# 0   2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3   2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8   2016-03-22 16:51:34                                         Seat_Arosa
# 9   2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
df.describe(include="all")
# Out:
#                 dateCrawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-03-10 15:36:24  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
# mean                    NaN          NaN     NaN       NaN    NaN    NaN
# std                     NaN          NaN     NaN       NaN    NaN    NaN
# min                     NaN          NaN     NaN       NaN    NaN    NaN
# 25%                     NaN          NaN     NaN       NaN    NaN    NaN
# 50%                     NaN          NaN     NaN       NaN    NaN    NaN
# 75%                     NaN          NaN     NaN       NaN    NaN    NaN
# max                     NaN          NaN     NaN       NaN    NaN    NaN
#
#        vehicleType  yearOfRegistration  gearbox       powerPS  model  \
# ...

# %% [markdown]
# Firstly we will clean the column names, make them uniform and in snake case for easier understanding and retrieval

# %%
new_cols = {'dateCrawled':'date_crawled','offerType':'offer_type',
           'vehicleType':'vehicle_type','yearOfRegistration':'registration_year',
           'powerPS':'power_PS','monthOfRegistration':'registration_month',
           'fuelType':'fuel_type','notRepairedDamage':'repaired_damage',
           'dateCreated':'date_created','nrOfPictures':'no_pictures',
           'postalCode':'postal_code','lastSeen':'last_seen'}
        
df.rename(columns=new_cols,inplace=True)
df.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'repaired_damage', 'date_created', 'no_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# The price and odometer columns need cleaning to make them of type numeric and emove '$' ',' 'kms' from the strings.

# %%
df.price = df.price.str.replace('$','')
df.price = df.price.str.replace(',','').astype('int32')
df.odometer = df.odometer.str.replace('km','')
df.odometer = df.odometer.str.replace(',','').astype('int32')
df.rename(columns={'odometer':'odometer_km'},inplace=True)

# %% [markdown]
# Looking at the disctribution of prices, the min - 0 and max - 9999999 seem as outliers. 0 being a cost is highly unlikely and could be those advertisements whose price point could not be retrieved. The 9999999 is on the extreme end and an absurd value.
# The registration month takes values from 1 to 12. month value with 0s are outliers in this data, and such data will be pruned.
# Similarly, registration year has two outlier values 1800 and 9999, these years arnt possible, thus pruning them.

# %%
df = df[df.price.between(1,12345678)]
df = df[df.registration_month != 0]
df = df[df.registration_year.between(1927,2019)]

# %% [markdown]
# All date/time columns are given in strings, this makes it difficult for information retrieval from such columns. Converting them to datetime data type

# %%
df.date_created = pd.to_datetime(df.date_created)
df.date_crawled = pd.to_datetime(df.date_crawled)
df.last_seen = pd.to_datetime(df.last_seen)

# %%
brands = df.brand.value_counts(normalize=True)[0:6].index

# %%
brands
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
mean_price_data = {}
for i in brands:
    p = df[df['brand'] == i].price.mean()
    mean_price_data[i]=p

# %%
mean_mileage_data = {}
for i in brands:
    p = df[df.brand == i].odometer_km.mean()
    mean_mileage_data[i] = p

# %%
mean_price = pd.Series(mean_price_data)
mean_mileage = pd.Series(mean_mileage_data)

# %%
df2 = pd.DataFrame(mean_price,columns=["mean_price"])
df2['mean_mileage'] = mean_mileage
df2
# Out:
#                 mean_price   mean_mileage
# volkswagen     5904.897294  128360.930736
# bmw            8837.038194  132584.763072
# opel           5813.933333  128880.952381
# mercedes_benz  8826.130854  130987.144169
# audi           9680.716251  128940.809969
# ford           7929.724274  123985.817942
